# %% [markdown]
# # Hausarbeit 1

# %% [markdown]
# Der *mtcars*-Datensatz enthält Informationen über verschiedene Automodelle und ist in der Datenanalyse und Statistik weit verbreitet. Er enthält 32 verschiedene Automodelle und unterschiedliche Variablen, die verschiedene Eigenschaften der Autos beschreiben, wie z.B. Hubraum, Zylinder, PS, Gewicht, und mehr. Ursprünglich wurden die Daten des \textit{mtcars}-Datensatzes vom amerikanischen Automagazin "Motor Trend" gesammelt und sind nun in R integriert, um statistische Analysen und Datenauswertungen zu erleichtern.

# %% [markdown]
# ## Frage 1: Datenüberblick

# %% [markdown]
# Zeigen Sie die ersten Zeilen des Datensatzes mtcars an.

# %%
data(mtcars)
head(???)

# %% [markdown]
# Wie viele Variablen sind im Datensatz enthalten?

# %% [markdown]
# **Antwort:** ???

# %% [markdown]
# ## Frage 2: Deskriptive Statistik

# %% [markdown]
# Zeigen Sie eine statistische Zusammenfassung des Datensatzes *mtcars* an.

# %%
summary(???)

# %% [markdown]
# Wie hoch ist der Durchschnittswert (Mittelwert) der Kraftstoffeffizienz (mpg) der Autos im Datensatz?

# %% [markdown]
# **Antwort:** ???

# %% [markdown]
# ## Frage 3: Visualisierung

# %% [markdown]
# Erstellen Sie ein Histogramm, das die Verteilung der PS der verschiedenen Autos im Datensatz zeigt.

# %%
hist(???)

# %% [markdown]
# Welche Schlüsse können Sie aus der Form der Verteilung ziehen?

# %% [markdown]
# **Antwort:** ???

# %% [markdown]
# ## Frage 4: Korrelation

# %% [markdown]
# Berechnen Sie die Korrelation zwischen der Anzahl der Zylinder (cyl) und dem Gewicht (wt) der Autos im Datensatz.

# %%
cor_cyl_wt <- cor(???, ???)
cor_cyl_wt

# %% [markdown]
# Wie lautet der Korrelationskoeffizient?

# %% [markdown]
# **Antwort:** ???

# %% [markdown]
# Gibt es eine positive oder negative Korrelation zwischen der Anzahl der Zylinder und dem Gewicht?

# %% [markdown]
# **Antwort:** ???
